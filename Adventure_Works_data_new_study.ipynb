# %% [markdown]
# <a href="https://colab.research.google.com/github/Joshua-Rooban-Rajan/Spotify-Data-Analysis/blob/main/Adventure_Works_data_new_study.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Use raw string for the file path
file_path = r'/content/Copy of Adventure Works 2020.xlsx'

# %%
#Loading the excel file
excel_file=pd.ExcelFile(file_path)

# %%
#getting the sheet names
sheet_names=excel_file.sheet_names
print(sheet_names)
# Out:
# ['Calendar', 'Products', 'Customers', 'Territory', 'Sales', 'dimProductSubCategory', 'dimProductCategory', 'BudgetPeriod', 'Budget']

# %%
# Load each sheet into a DataFrame
dataframes = {sheet: excel_file.parse(sheet) for sheet in sheet_names}

# Display the first few rows of each DataFrame
for sheet, df in dataframes.items():
    print(f"\nSheet: {sheet}")
    print(df.head())
# Out:
# Sheet: Calendar
#    ID       Date  DayNumberOfWeek   DayName MonthName  MonthNumberOfYear  \
# 0   1 2016-07-01                6    Friday      July                  7
# 1   2 2016-07-02                7  Saturday      July                  7
# 2   3 2016-07-03                1    Sunday      July                  7
# 3   4 2016-07-04                2    Monday      July                  7
# 4   5 2016-07-05                3   Tuesday      July                  7
#
#    DayNumberOfYear  WeekNumberOfYear  CalendarQuarter  CalendarYear  \
# 0              183                27                3          2016
# 1              184                27                3          2016
# 2              185                27                3          2016
# 3              186                28                3          2016
# 4              187                28                3          2016
#
#    Fiscal Year  FiscalQuarter  DayNumberOfMonth  FiscalSemester  Period  \
# ...

# %%
for sheet, df in dataframes.items():
    print(f"\nSheet: {sheet}")
    print(df.info())
    print(df.isnull().sum())
    # Perform any cleaning specific to this DataFrame
    # For example:
    # df.fillna(method='ffill', inplace=True)
    # df.drop_duplicates(inplace=True)
# Out:
# Sheet: Calendar
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1279 entries, 0 to 1278
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID                 1279 non-null   int64
#  1   Date               1279 non-null   datetime64[ns]
#  2   DayNumberOfWeek    1279 non-null   int64
#  3   DayName            1279 non-null   object
#  4   MonthName          1279 non-null   object
#  5   MonthNumberOfYear  1279 non-null   int64
#  6   DayNumberOfYear    1279 non-null   int64
#  7   WeekNumberOfYear   1279 non-null   int64
#  8   CalendarQuarter    1279 non-null   int64
#  9   CalendarYear       1279 non-null   int64
#  10  Fiscal Year        1279 non-null   int64
#  11  FiscalQuarter      1279 non-null   int64
#  12  DayNumberOfMonth   1279 non-null   int64
#  13  FiscalSemester     1279 non-null   int64
#  14  Period             1279 non-null   int64
# ...
